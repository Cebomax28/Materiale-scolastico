# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

print("Librerie caricate con successo")
# Out:
# Librerie caricate con successo

# %%
DATASET_PATH = "../DATASET"
percorso = os.path.join(DATASET_PATH, "dataset_dt_anger_60k.txt")

with open(percorso, "r", encoding="utf-8", errors="replace") as f:
    righe = [riga.strip() for riga in f if riga.strip()]
    
print(righe)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 DATASET_PATH = "../DATASET"
#       2 percorso = os.path.join(DATASET_PATH, "dataset_dt_anger_60k.txt")
# ----> 4 with open(percorso, "r", encoding="utf-8", errors="replace") as f:
#       5     righe = [riga.strip() for riga in f if riga.strip()]
#       7 print(righe)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../DATASET\\dataset_dt_anger_60k.txt'
