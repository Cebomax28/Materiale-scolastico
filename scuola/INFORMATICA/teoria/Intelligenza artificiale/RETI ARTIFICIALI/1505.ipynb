# %%
# PERCETTRONE
# 1958

# Percettrone che distingue mail spam da no spam

# x1 = contiene la parola gratis?
# x2 = il mittente è nella mia rubrica?
# x3 = contiene un link sospetto?

# %%
import numpy as np

def step_function(z):
    return z >= 0

# Simuliamo un percettrone gia addestrato
def perceptron
